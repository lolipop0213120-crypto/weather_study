# %%
import pandas as pandas
# Out:
# Running cells with 'weather_study (3.12.9) (Python 3.12.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/lolip/Documents/weather_study/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
import pandas as pd
# Out:
# Running cells with 'weather_study (3.12.9) (Python 3.12.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/lolip/Documents/weather_study/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
import pandas as pd
# Out:
# Running cells with 'weather_study (3.12.9) (Python 3.12.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/lolip/Documents/weather_study/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
import pandas as pd
# Out:
# Running cells with 'weather_study (3.12.9) (Python 3.12.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/lolip/Documents/weather_study/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
import pandas as pd
# Out:
# Running cells with 'weather_study (3.12.9) (Python 3.12.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/lolip/Documents/weather_study/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
import pandas as pd
